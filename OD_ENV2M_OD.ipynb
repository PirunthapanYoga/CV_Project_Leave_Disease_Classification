# %%
import numpy as np
import cv2
import os
from os import listdir
import tensorflow as tf
import pickle
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense, Reshape
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
default_image_size = tuple((256, 256))
resized_image_size = tuple((227,227))
image_size = 0
directory_root = 'E:\\PROJECT_MODIFIED\\Real_Image\\Resized\\227x227'

# %%
# Function to convert image to array.
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, resized_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
# Reading the images from the dataset folder.
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list[:]:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed!")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing BANANA_DISEASED_LEAF SPOT ...
# [INFO] Processing BANANA_HEALTHY ...
# [INFO] Processing BLACK-PEPPER_DISEASED_ANTHRACNOSE ...
# [INFO] Processing BLACK-PEPPER_HEALTHY ...
# [INFO] Processing BRINJAL_DISEASED_BLIGHT ...
# [INFO] Processing BRINJAL_DISEASED_COMPLEX ...
# [INFO] Processing BRINJAL_DISEASED_LEAF CURL ...
# [INFO] Processing BRINJAL_DISEASED_LEAF SPOT ...
# [INFO] Processing BRINJAL_DISEASED_MOSAIC ...
# [INFO] Processing BRINJAL_HEALTHY ...
# [INFO] Processing CABBAGE_HEALTHY ...
# [INFO] Processing CASAVA_HEALTHY ...
# [INFO] Processing CASSAVA_DISEASED_LEAF SPOT ...
# [INFO] Processing CASSAVA_DISEASED_MOSAIC ...
# [INFO] Processing CHILLI-PEPPER_CHLOROSIS ...
# [INFO] Processing CHILLI-PEPPER_DISEASED_LEAF CURL ...
# [INFO] Processing CHILLI-PEPPER_DISEASED_LEAF SPOT ...
# [INFO] Processing CHILLI-PEPPER_DISEASED_MOSIAC ...
# [INFO] Processing CHILLI-PEPPER_HEALTHY ...
# [INFO] Processing CITRUS_DISEASED_LEAVE SPOT ...
# [INFO] Processing CITRUS_DISEASED_MITE ...
# [INFO] Processing CITRUS_DISEASED_MOLD ...
# [INFO] Processing CITRUS_DISEASED_YELLOWING ...
# [INFO] Processing CITRUS_HEALTH ...
# [INFO] Processing GUAVA_DISEASED_BLIGHT ...
# [INFO] Processing GUAVA_DISEASED_HEALTHY ...
# [INFO] Processing GUAVA_DISEASED_LEAF SPOT ...
# [INFO] Processing GUAVA_DISEASED_PEST ...
# [INFO] Processing GUAVA_DISEASED_SOOTY MOLD ...
# [INFO] Processing GUAVA_DISEASES_ANTHRACNOSE ...
# [INFO] Processing OKRA_DISEASED_LEAF CUEL ...
# [INFO] Processing OKRA_DISEASED_LEAF SPOT ...
# [INFO] Processing OKRA_DISEASED_MOSAIC ...
# [INFO] Processing OKRA_HEALTHY ...
# [INFO] Processing PAPAYA_HEALTHY ...
# [INFO] Image loading completed!

# %%
# Assign the classes to images.
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
n_classes = len(label_binarizer.classes_)

# %%
from collections import Counter
print(Counter(label_list).keys() )
print(Counter(label_list).values())
# Out:
# dict_keys(['BANANA_DISEASED_LEAF SPOT', 'BANANA_HEALTHY', 'BLACK-PEPPER_DISEASED_ANTHRACNOSE', 'BLACK-PEPPER_HEALTHY', 'BRINJAL_DISEASED_BLIGHT', 'BRINJAL_DISEASED_COMPLEX', 'BRINJAL_DISEASED_LEAF CURL', 'BRINJAL_DISEASED_LEAF SPOT', 'BRINJAL_DISEASED_MOSAIC', 'BRINJAL_HEALTHY', 'CABBAGE_HEALTHY', 'CASAVA_HEALTHY', 'CASSAVA_DISEASED_LEAF SPOT', 'CASSAVA_DISEASED_MOSAIC', 'CHILLI-PEPPER_CHLOROSIS', 'CHILLI-PEPPER_DISEASED_LEAF CURL', 'CHILLI-PEPPER_DISEASED_LEAF SPOT', 'CHILLI-PEPPER_DISEASED_MOSIAC', 'CHILLI-PEPPER_HEALTHY', 'CITRUS_DISEASED_LEAVE SPOT', 'CITRUS_DISEASED_MITE', 'CITRUS_DISEASED_MOLD', 'CITRUS_DISEASED_YELLOWING', 'CITRUS_HEALTH', 'GUAVA_DISEASED_BLIGHT', 'GUAVA_DISEASED_HEALTHY', 'GUAVA_DISEASED_LEAF SPOT', 'GUAVA_DISEASED_PEST', 'GUAVA_DISEASED_SOOTY MOLD', 'GUAVA_DISEASES_ANTHRACNOSE', 'OKRA_DISEASED_LEAF CUEL', 'OKRA_DISEASED_LEAF SPOT', 'OKRA_DISEASED_MOSAIC', 'OKRA_HEALTHY', 'PAPAYA_HEALTHY'])
# dict_values([38, 33, 22, 44, 7, 31, 18, 103, 16, 202, 83, 7, 23, 212, 22, 179, 14, 33, 72, 5, 123, 86, 88, 22, 6, 32, 51, 54, 27, 36, 1, 22, 85, 30, 17])

# %%
labels = len(label_binarizer.classes_)
print(labels)
# Out:
# 35

# %%
# Convert the array to a NumPy list and normalise it.
np_image_list = np.array(image_list, dtype = np.float16) / 225.0
print("Total Images" , " : " ,len(np_image_list))
del image_list
# Out:
# Total Images  :  1844

# %%
print("[INFO] Spliting data into train set and test set ...")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size = 0.2, random_state = 42) 
print("[INFO] Spliting complete!")
print("x_Train" ," : " , len(x_train))
print("y_Train" ," : " , len(y_train))
print("x_Test" ," : " , len(x_test))
print("y_Test" ," : " , len(y_test))
del np_image_list
del image_labels
# Out:
# [INFO] Spliting data into train set and test set ...
# [INFO] Spliting complete!
# x_Train  :  1475
# y_Train  :  1475
# x_Test  :  369
# y_Test  :  369

# %%
aug = ImageDataGenerator()

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2
import os, gc, sys, glob
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn import metrics


import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model, load_model
from keras import applications
from keras.callbacks import ReduceLROnPlateau

from keras.layers import LayerNormalization
from keras.metrics import categorical_accuracy
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
import keras.backend as K

dtype = 'float16'
K.set_floatx(dtype)
K.set_epsilon(1e-4)

# %%
MODEL_NAME = "OD_ENV2BM_OD.h5"

# %%
img_rows, img_cols, img_channel = 227,227, 3

base_model =tf.keras.applications.EfficientNetV2M(
    include_top=False,
    input_shape=(img_rows, img_cols, img_channel),
    pooling='avg',
)

print(base_model.summary())
# Out:
# Model: "efficientnetv2-m"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 227, 227, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 114, 114, 24  648         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 114, 114, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 114, 114, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 114, 114, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 114, 114, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 114, 114, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 114, 114, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 114, 114, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 114, 114, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 114, 114, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 114, 114, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 114, 114, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 114, 114, 24  5184        ['block1b_add[0][0]']
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 114, 114, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  block1c_project_activation (Ac  (None, 114, 114, 24  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  block1c_drop (Dropout)         (None, 114, 114, 24  0           ['block1c_project_activation[0][0
#                                 )                                ]']
#
#  block1c_add (Add)              (None, 114, 114, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 57, 57, 96)   20736       ['block1c_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 57, 57, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 57, 57, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 57, 57, 48)   4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 57, 57, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 57, 57, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 57, 57, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 57, 57, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 57, 57, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 57, 57, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 57, 57, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 57, 57, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 57, 57, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 57, 57, 192)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2e_expand_activation[0][0]
#                                                                  ']
#
#  block2e_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 57, 57, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 57, 57, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 29, 29, 192)  82944       ['block2e_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 29, 29, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 29, 29, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 29, 29, 80)   15360       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 29, 29, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 29, 29, 320)  230400      ['block3a_project_bn[0][0]']
#  block3b_expand_bn (BatchNormal  (None, 29, 29, 320)  1280       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 29, 29, 320)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 29, 29, 80)   25600       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 29, 29, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 29, 29, 80)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 29, 29, 80)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 29, 29, 320)  230400      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 29, 29, 320)  1280       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 29, 29, 320)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 29, 29, 80)   25600       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 29, 29, 80)  320         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 29, 29, 80)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 29, 29, 80)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 29, 29, 320)  230400      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 29, 29, 320)  1280       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 29, 29, 320)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 29, 29, 80)   25600       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 29, 29, 80)  320         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 29, 29, 80)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 29, 29, 80)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 29, 29, 320)  230400      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 29, 29, 320)  1280       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 29, 29, 320)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 29, 29, 80)   25600       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 29, 29, 80)  320         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_drop (Dropout)         (None, 29, 29, 80)   0           ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)              (None, 29, 29, 80)   0           ['block3e_drop[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 29, 29, 320)  25600       ['block3e_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 29, 29, 320)  1280       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 29, 29, 320)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 15, 15, 320)  2880       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 15, 15, 320)  1280       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 15, 15, 320)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 320)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 320)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 20)     6420        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 320)    6720        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 15, 15, 320)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 15, 15, 160)  51200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 15, 15, 640)  102400      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 15, 15, 640)  2560       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 15, 15, 640)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 15, 15, 640)  5760       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 15, 15, 640)  2560       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 15, 15, 640)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 640)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 15, 15, 640)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 15, 15, 160)  102400      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 15, 15, 160)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 15, 15, 160)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 15, 15, 640)  102400      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 15, 15, 640)  2560       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 15, 15, 640)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 15, 15, 640)  5760       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 15, 15, 640)  2560       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 15, 15, 640)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 640)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 15, 15, 640)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 15, 15, 160)  102400      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 15, 15, 160)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 15, 15, 160)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 15, 15, 640)  102400      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 15, 15, 640)  2560       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 15, 15, 640)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 15, 15, 640)  5760       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 15, 15, 640)  2560       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 15, 15, 640)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 640)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 15, 15, 640)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 15, 15, 160)  102400      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 15, 15, 160)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 15, 15, 160)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 15, 15, 640)  102400      ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 15, 15, 640)  2560       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 15, 15, 640)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 15, 15, 640)  5760       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 15, 15, 640)  2560       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 15, 15, 640)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 640)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4e_se_reshape[0][0]']
#  block4e_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 15, 15, 640)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 15, 15, 160)  102400      ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 15, 15, 160)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 15, 15, 160)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 15, 15, 640)  102400      ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 15, 15, 640)  2560       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 15, 15, 640)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 15, 15, 640)  5760       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 15, 15, 640)  2560       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 15, 15, 640)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 640)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 640)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 40)     25640       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 640)    26240       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 15, 15, 640)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 15, 15, 160)  102400      ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 15, 15, 160)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 15, 15, 160)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block4g_expand_conv (Conv2D)   (None, 15, 15, 640)  102400      ['block4f_add[0][0]']
#
#  block4g_expand_bn (BatchNormal  (None, 15, 15, 640)  2560       ['block4g_expand_conv[0][0]']
#  ization)
#
#  block4g_expand_activation (Act  (None, 15, 15, 640)  0          ['block4g_expand_bn[0][0]']
#  ivation)
#
#  block4g_dwconv2 (DepthwiseConv  (None, 15, 15, 640)  5760       ['block4g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4g_bn (BatchNormalization  (None, 15, 15, 640)  2560       ['block4g_dwconv2[0][0]']
#  )
#
#  block4g_activation (Activation  (None, 15, 15, 640)  0          ['block4g_bn[0][0]']
#  )
#
#  block4g_se_squeeze (GlobalAver  (None, 640)         0           ['block4g_activation[0][0]']
# ...
#
#  block7b_dwconv2 (DepthwiseConv  (None, 8, 8, 3072)  27648       ['block7b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7b_bn (BatchNormalization  (None, 8, 8, 3072)  12288       ['block7b_dwconv2[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 8, 8, 3072)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3072)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 8, 8, 3072)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 8, 8, 512)    1572864     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 8, 8, 512)   2048        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 8, 8, 512)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 8, 8, 512)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 8, 8, 3072)   1572864     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 8, 8, 3072)  12288       ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 8, 8, 3072)  0           ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv2 (DepthwiseConv  (None, 8, 8, 3072)  27648       ['block7c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7c_bn (BatchNormalization  (None, 8, 8, 3072)  12288       ['block7c_dwconv2[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 8, 8, 3072)  0           ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3072)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 8, 8, 3072)   0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 8, 8, 512)    1572864     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 8, 8, 512)   2048        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 8, 8, 512)    0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 8, 8, 512)    0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 8, 8, 3072)   1572864     ['block7c_add[0][0]']
#
#  block7d_expand_bn (BatchNormal  (None, 8, 8, 3072)  12288       ['block7d_expand_conv[0][0]']
#  ization)
#
#  block7d_expand_activation (Act  (None, 8, 8, 3072)  0           ['block7d_expand_bn[0][0]']
#  ivation)
#
#  block7d_dwconv2 (DepthwiseConv  (None, 8, 8, 3072)  27648       ['block7d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7d_bn (BatchNormalization  (None, 8, 8, 3072)  12288       ['block7d_dwconv2[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 8, 8, 3072)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3072)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 8, 8, 3072)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 8, 8, 512)    1572864     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 8, 8, 512)   2048        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 8, 8, 512)    0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 8, 8, 512)    0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 8, 8, 3072)   1572864     ['block7d_add[0][0]']
#
#  block7e_expand_bn (BatchNormal  (None, 8, 8, 3072)  12288       ['block7e_expand_conv[0][0]']
#  ization)
#
#  block7e_expand_activation (Act  (None, 8, 8, 3072)  0           ['block7e_expand_bn[0][0]']
#  ivation)
#
#  block7e_dwconv2 (DepthwiseConv  (None, 8, 8, 3072)  27648       ['block7e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7e_bn (BatchNormalization  (None, 8, 8, 3072)  12288       ['block7e_dwconv2[0][0]']
#  )
#
#  block7e_activation (Activation  (None, 8, 8, 3072)  0           ['block7e_bn[0][0]']
#  )
#
#  block7e_se_squeeze (GlobalAver  (None, 3072)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3072)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 128)    393344      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3072)   396288      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 8, 8, 3072)   0           ['block7e_activation[0][0]',
#                                                                   'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 8, 8, 512)    1572864     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 8, 8, 512)   2048        ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_drop (Dropout)         (None, 8, 8, 512)    0           ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)              (None, 8, 8, 512)    0           ['block7e_drop[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  top_conv (Conv2D)              (None, 8, 8, 1280)   655360      ['block7e_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 8, 8, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 8, 8, 1280)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 53,150,388
# Trainable params: 52,858,356
# Non-trainable params: 292,032
# __________________________________________________________________________________________________
# None

# %%
outputs = tf.keras.layers.Dense(labels, activation='softmax')(base_model.output)
model = tf.keras.Model(inputs=base_model.input, outputs=outputs)

# %%
EPOCHS = 100
INIT_LR = 1e-4
Decay = 1e-5

# compile the model
opt = opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)

model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer=opt)

print("[INFO] Training network...")

# Train
checkpoint = ModelCheckpoint(MODEL_NAME, monitor = 'val_accuracy', verbose = 1, save_best_only = True, save_weights_only = False, mode = 'max')


history = model.fit(
    aug.flow(x_train, y_train, shuffle = False),
    validation_data = (x_test, y_test),
    validation_freq=1,
    batch_size = 32,
    callbacks = [checkpoint],
    epochs = EPOCHS,)
# Out:
# [INFO] Training network...
# Epoch 1/100
# 47/47 [==============================] - ETA: 0s - loss: 3.2871 - accuracy: 0.1362
# Epoch 1: val_accuracy improved from -inf to 0.03793, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 42s 464ms/step - loss: 3.2871 - accuracy: 0.1362 - val_loss: nan - val_accuracy: 0.0379
# Epoch 2/100
# 47/47 [==============================] - ETA: 0s - loss: 2.4473 - accuracy: 0.3247
# Epoch 2: val_accuracy did not improve from 0.03793
# 47/47 [==============================] - 17s 353ms/step - loss: 2.4473 - accuracy: 0.3247 - val_loss: nan - val_accuracy: 0.0108
# Epoch 3/100
# 47/47 [==============================] - ETA: 0s - loss: 2.2285 - accuracy: 0.4055
# Epoch 3: val_accuracy did not improve from 0.03793
# 47/47 [==============================] - 17s 353ms/step - loss: 2.2285 - accuracy: 0.4055 - val_loss: nan - val_accuracy: 0.0325
# Epoch 4/100
# 47/47 [==============================] - ETA: 0s - loss: 2.0566 - accuracy: 0.4514
# Epoch 4: val_accuracy improved from 0.03793 to 0.04877, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 385ms/step - loss: 2.0566 - accuracy: 0.4514 - val_loss: nan - val_accuracy: 0.0488
# Epoch 5/100
# 47/47 [==============================] - ETA: 0s - loss: 1.9375 - accuracy: 0.4712
# Epoch 5: val_accuracy improved from 0.04877 to 0.08673, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 386ms/step - loss: 1.9375 - accuracy: 0.4712 - val_loss: nan - val_accuracy: 0.0867
# Epoch 6/100
# 47/47 [==============================] - ETA: 0s - loss: 1.7871 - accuracy: 0.5024
# Epoch 6: val_accuracy did not improve from 0.08673
# 47/47 [==============================] - 17s 353ms/step - loss: 1.7871 - accuracy: 0.5024 - val_loss: nan - val_accuracy: 0.0108
# Epoch 7/100
# 47/47 [==============================] - ETA: 0s - loss: 1.8184 - accuracy: 0.4880
# Epoch 7: val_accuracy did not improve from 0.08673
# 47/47 [==============================] - 17s 354ms/step - loss: 1.8184 - accuracy: 0.4880 - val_loss: nan - val_accuracy: 0.0434
# Epoch 8/100
# 47/47 [==============================] - ETA: 0s - loss: 1.9092 - accuracy: 0.4658
# Epoch 8: val_accuracy did not improve from 0.08673
# 47/47 [==============================] - 17s 353ms/step - loss: 1.9092 - accuracy: 0.4658 - val_loss: nan - val_accuracy: 0.0325
# Epoch 9/100
# 47/47 [==============================] - ETA: 0s - loss: 1.7490 - accuracy: 0.5117
# Epoch 9: val_accuracy improved from 0.08673 to 0.26025, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 383ms/step - loss: 1.7490 - accuracy: 0.5117 - val_loss: 3.7891 - val_accuracy: 0.2603
# Epoch 10/100
# 47/47 [==============================] - ETA: 0s - loss: 1.5498 - accuracy: 0.5581
# Epoch 10: val_accuracy improved from 0.26025 to 0.34424, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 387ms/step - loss: 1.5498 - accuracy: 0.5581 - val_loss: 4.4062 - val_accuracy: 0.3442
# Epoch 11/100
# 47/47 [==============================] - ETA: 0s - loss: 1.5703 - accuracy: 0.5498
# Epoch 11: val_accuracy improved from 0.34424 to 0.40918, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 392ms/step - loss: 1.5703 - accuracy: 0.5498 - val_loss: 2.2559 - val_accuracy: 0.4092
# Epoch 12/100
# 47/47 [==============================] - ETA: 0s - loss: 1.5322 - accuracy: 0.5571
# Epoch 12: val_accuracy did not improve from 0.40918
# 47/47 [==============================] - 17s 353ms/step - loss: 1.5322 - accuracy: 0.5571 - val_loss: 2.8613 - val_accuracy: 0.3469
# Epoch 13/100
# 47/47 [==============================] - ETA: 0s - loss: 1.5527 - accuracy: 0.5532
# Epoch 13: val_accuracy did not improve from 0.40918
# 47/47 [==============================] - 17s 352ms/step - loss: 1.5527 - accuracy: 0.5532 - val_loss: 5.2070 - val_accuracy: 0.1653
# Epoch 14/100
# 47/47 [==============================] - ETA: 0s - loss: 1.7148 - accuracy: 0.5161
# Epoch 14: val_accuracy did not improve from 0.40918
# 47/47 [==============================] - 17s 353ms/step - loss: 1.7148 - accuracy: 0.5161 - val_loss: nan - val_accuracy: 0.1437
# Epoch 15/100
# 47/47 [==============================] - ETA: 0s - loss: 1.8701 - accuracy: 0.4719
# Epoch 15: val_accuracy did not improve from 0.40918
# 47/47 [==============================] - 17s 352ms/step - loss: 1.8701 - accuracy: 0.4719 - val_loss: nan - val_accuracy: 0.2546
# Epoch 16/100
# 47/47 [==============================] - ETA: 0s - loss: 1.8037 - accuracy: 0.4902
# Epoch 16: val_accuracy improved from 0.40918 to 0.48511, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 384ms/step - loss: 1.8037 - accuracy: 0.4902 - val_loss: 2.0273 - val_accuracy: 0.4851
# Epoch 17/100
# 47/47 [==============================] - ETA: 0s - loss: 1.5869 - accuracy: 0.5439
# Epoch 17: val_accuracy improved from 0.48511 to 0.58252, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 384ms/step - loss: 1.5869 - accuracy: 0.5439 - val_loss: 1.4678 - val_accuracy: 0.5825
# Epoch 18/100
# 47/47 [==============================] - ETA: 0s - loss: 1.4805 - accuracy: 0.5806
# Epoch 18: val_accuracy did not improve from 0.58252
# 47/47 [==============================] - 17s 353ms/step - loss: 1.4805 - accuracy: 0.5806 - val_loss: 1.5732 - val_accuracy: 0.5771
# Epoch 19/100
# 47/47 [==============================] - ETA: 0s - loss: 1.4941 - accuracy: 0.5728
# Epoch 19: val_accuracy did not improve from 0.58252
# 47/47 [==============================] - 17s 358ms/step - loss: 1.4941 - accuracy: 0.5728 - val_loss: 1.7021 - val_accuracy: 0.5122
# Epoch 20/100
# 47/47 [==============================] - ETA: 0s - loss: 1.4902 - accuracy: 0.5708
# Epoch 20: val_accuracy did not improve from 0.58252
# 47/47 [==============================] - 17s 353ms/step - loss: 1.4902 - accuracy: 0.5708 - val_loss: 1.4570 - val_accuracy: 0.5581
# Epoch 21/100
# 47/47 [==============================] - ETA: 0s - loss: 1.4248 - accuracy: 0.5884
# Epoch 21: val_accuracy did not improve from 0.58252
# 47/47 [==============================] - 17s 355ms/step - loss: 1.4248 - accuracy: 0.5884 - val_loss: nan - val_accuracy: 0.0108
# Epoch 22/100
# 47/47 [==============================] - ETA: 0s - loss: 1.5195 - accuracy: 0.5479
# Epoch 22: val_accuracy improved from 0.58252 to 0.61230, saving model to OD_ENV2BM_AD.h5
# 47/47 [==============================] - 18s 389ms/step - loss: 1.5195 - accuracy: 0.5479 - val_loss: 1.3262 - val_accuracy: 0.6123
# Epoch 23/100
# 47/47 [==============================] - ETA: 0s - loss: