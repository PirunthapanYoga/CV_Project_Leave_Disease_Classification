# %%
import numpy as np
import cv2
import os
from os import listdir
import tensorflow as tf
import pickle
from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Flatten, Dropout, Dense, Reshape
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
default_image_size = tuple((256, 256))
resized_image_size = tuple((227,227))
image_size = 0
directory_root = 'E:\\PROJECT_MODIFIED\\Augmented\\Resized\\227x227'

# %%
# Function to convert image to array.
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, resized_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
# Reading the images from the dataset folder.
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    for plant_folder in root_dir :
        plant_disease_folder_list = listdir(f"{directory_root}/{plant_folder}")
        
        for disease_folder in plant_disease_folder_list :
            # remove .DS_Store from list
            if disease_folder == ".DS_Store" :
                plant_disease_folder_list.remove(disease_folder)

        for plant_disease_folder in plant_disease_folder_list:
            print(f"[INFO] Processing {plant_disease_folder} ...")
            plant_disease_image_list = listdir(f"{directory_root}/{plant_folder}/{plant_disease_folder}/")
                
            for single_plant_disease_image in plant_disease_image_list :
                if single_plant_disease_image == ".DS_Store" :
                    plant_disease_image_list.remove(single_plant_disease_image)

            for image in plant_disease_image_list[:]:
                image_directory = f"{directory_root}/{plant_folder}/{plant_disease_folder}/{image}"
                if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                    image_list.append(convert_image_to_array(image_directory))
                    label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed!")  
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing BANANA_DISEASED_LEAF SPOT ...
# [INFO] Processing BANANA_HEALTHY ...
# [INFO] Processing BLACK-PEPPER_DISEASED_ANTHRACNOSE ...
# [INFO] Processing BLACK-PEPPER_HEALTHY ...
# [INFO] Processing BRINJAL_DISEASED_BLIGHT ...
# [INFO] Processing BRINJAL_DISEASED_COMPLEX ...
# [INFO] Processing BRINJAL_DISEASED_LEAF CURL ...
# [INFO] Processing BRINJAL_DISEASED_LEAF SPOT ...
# [INFO] Processing BRINJAL_DISEASED_MOSAIC ...
# [INFO] Processing BRINJAL_HEALTHY ...
# [INFO] Processing CABBAGE_HEALTHY ...
# [INFO] Processing CASAVA_HEALTHY ...
# [INFO] Processing CASSAVA_DISEASED_LEAF SPOT ...
# [INFO] Processing CASSAVA_DISEASED_MOSAIC ...
# [INFO] Processing CHILLI-PEPPER_CHLOROSIS ...
# [INFO] Processing CHILLI-PEPPER_DISEASED_LEAF CURL ...
# [INFO] Processing CHILLI-PEPPER_DISEASED_LEAF SPOT ...
# [INFO] Processing CHILLI-PEPPER_DISEASED_MOSIAC ...
# [INFO] Processing CHILLI-PEPPER_HEALTHY ...
# [INFO] Processing CITRUS_DISEASED_LEAVE SPOT ...
# [INFO] Processing CITRUS_DISEASED_MITE ...
# [INFO] Processing CITRUS_DISEASED_MOLD ...
# [INFO] Processing CITRUS_DISEASED_YELLOWING ...
# [INFO] Processing CITRUS_HEALTH ...
# [INFO] Processing GUAVA_DISEASED_BLIGHT ...
# [INFO] Processing GUAVA_DISEASED_HEALTHY ...
# [INFO] Processing GUAVA_DISEASED_LEAF SPOT ...
# [INFO] Processing GUAVA_DISEASED_PEST ...
# [INFO] Processing GUAVA_DISEASED_SOOTY MOLD ...
# [INFO] Processing GUAVA_DISEASES_ANTHRACNOSE ...
# [INFO] Processing OKRA_DISEASED_LEAF CUEL ...
# [INFO] Processing OKRA_DISEASED_LEAF SPOT ...
# [INFO] Processing OKRA_DISEASED_MOSAIC ...
# [INFO] Processing OKRA_HEALTHY ...
# [INFO] Processing PAPAYA_HEALTHY ...
# [INFO] Image loading completed!

# %%
# Assign the classes to images.
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
n_classes = len(label_binarizer.classes_)

# %%
from collections import Counter
print(Counter(label_list).keys() )
print(Counter(label_list).values())
# Out:
# dict_keys(['BANANA_DISEASED_LEAF SPOT', 'BANANA_HEALTHY', 'BLACK-PEPPER_DISEASED_ANTHRACNOSE', 'BLACK-PEPPER_HEALTHY', 'BRINJAL_DISEASED_BLIGHT', 'BRINJAL_DISEASED_COMPLEX', 'BRINJAL_DISEASED_LEAF CURL', 'BRINJAL_DISEASED_LEAF SPOT', 'BRINJAL_DISEASED_MOSAIC', 'BRINJAL_HEALTHY', 'CABBAGE_HEALTHY', 'CASAVA_HEALTHY', 'CASSAVA_DISEASED_LEAF SPOT', 'CASSAVA_DISEASED_MOSAIC', 'CHILLI-PEPPER_CHLOROSIS', 'CHILLI-PEPPER_DISEASED_LEAF CURL', 'CHILLI-PEPPER_DISEASED_LEAF SPOT', 'CHILLI-PEPPER_DISEASED_MOSIAC', 'CHILLI-PEPPER_HEALTHY', 'CITRUS_DISEASED_LEAVE SPOT', 'CITRUS_DISEASED_MITE', 'CITRUS_DISEASED_MOLD', 'CITRUS_DISEASED_YELLOWING', 'CITRUS_HEALTH', 'GUAVA_DISEASED_BLIGHT', 'GUAVA_DISEASED_HEALTHY', 'GUAVA_DISEASED_LEAF SPOT', 'GUAVA_DISEASED_PEST', 'GUAVA_DISEASED_SOOTY MOLD', 'GUAVA_DISEASES_ANTHRACNOSE', 'OKRA_DISEASED_LEAF CUEL', 'OKRA_DISEASED_LEAF SPOT', 'OKRA_DISEASED_MOSAIC', 'OKRA_HEALTHY', 'PAPAYA_HEALTHY'])
# dict_values([228, 198, 132, 264, 42, 186, 108, 618, 96, 1212, 498, 42, 138, 1272, 132, 1074, 84, 198, 432, 30, 738, 516, 528, 132, 36, 192, 306, 324, 162, 216, 6, 132, 510, 180, 102])

# %%
labels = len(label_binarizer.classes_)
print(labels)
# Out:
# 35

# %%
# Convert the array to a NumPy list and normalise it.
np_image_list = np.array(image_list, dtype = np.float16) / 225.0
print("Total Images" , " : " ,len(np_image_list))
del image_list
# Out:
# Total Images  :  11064

# %%
print("[INFO] Spliting data into train set and test set ...")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size = 0.2, random_state = 42) 
print("[INFO] Spliting complete!")
print("x_Train" ," : " , len(x_train))
print("y_Train" ," : " , len(y_train))
print("x_Test" ," : " , len(x_test))
print("y_Test" ," : " , len(y_test))
del np_image_list
del image_labels
# Out:
# [INFO] Spliting data into train set and test set ...
# [INFO] Spliting complete!
# x_Train  :  8851
# y_Train  :  8851
# x_Test  :  2213
# y_Test  :  2213

# %%
aug = ImageDataGenerator()

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import cv2
import os, gc, sys, glob
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn import metrics

import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model, load_model
from keras import applications
from keras.callbacks import ReduceLROnPlateau

from keras.layers import LayerNormalization
from keras.metrics import categorical_accuracy
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
img_rows, img_cols, img_channel = 227,227, 3

base_model =tf.keras.applications.EfficientNetV2S(
    include_top=False,
    input_shape=(img_rows, img_cols, img_channel),
    pooling='avg',
)

print(base_model.summary())
# Out:
# Model: "efficientnetv2-s"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 227, 227, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 114, 114, 24  648         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 114, 114, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 114, 114, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 114, 114, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 114, 114, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 114, 114, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 114, 114, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 114, 114, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 114, 114, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 114, 114, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 114, 114, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 114, 114, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 57, 57, 96)   20736       ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 57, 57, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 57, 57, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 57, 57, 48)   4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 57, 57, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 57, 57, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 57, 57, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#  block2c_expand_activation (Act  (None, 57, 57, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 57, 57, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 57, 57, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 57, 57, 192)  82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 57, 57, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 57, 57, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 57, 57, 48)   9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 57, 57, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 57, 57, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 57, 57, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 29, 29, 192)  82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 29, 29, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 29, 29, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 29, 29, 64)   12288       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 29, 29, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 29, 29, 256)  147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 29, 29, 256)  1024       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 29, 29, 256)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 29, 29, 64)   16384       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 29, 29, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 29, 29, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 29, 29, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 29, 29, 256)  147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 29, 29, 256)  1024       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 29, 29, 256)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 29, 29, 64)   16384       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 29, 29, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 29, 29, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 29, 29, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 29, 29, 256)  147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 29, 29, 256)  1024       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 29, 29, 256)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 29, 29, 64)   16384       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 29, 29, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 29, 29, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 29, 29, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 29, 29, 256)  16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 29, 29, 256)  1024       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 29, 29, 256)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 15, 15, 256)  2304       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 15, 15, 256)  1024       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 15, 15, 256)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 256)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 256)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 16)     4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 256)    4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 15, 15, 256)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 15, 15, 128)  32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 15, 15, 128)  512        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 15, 15, 512)  65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 15, 15, 512)  2048       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 15, 15, 512)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 15, 15, 512)  4608       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 15, 15, 512)  2048       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 15, 15, 512)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 512)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 15, 15, 512)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 15, 15, 128)  65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 15, 15, 128)  512        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 15, 15, 128)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 15, 15, 128)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 15, 15, 512)  65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 15, 15, 512)  2048       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 15, 15, 512)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 15, 15, 512)  4608       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 15, 15, 512)  2048       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 15, 15, 512)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 512)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 15, 15, 512)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 15, 15, 128)  65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 15, 15, 128)  512        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 15, 15, 128)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 15, 15, 128)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 15, 15, 512)  65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 15, 15, 512)  2048       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 15, 15, 512)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 15, 15, 512)  4608       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 15, 15, 512)  2048       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 15, 15, 512)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 512)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 15, 15, 512)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 15, 15, 128)  65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 15, 15, 128)  512        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 15, 15, 128)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 15, 15, 128)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 15, 15, 512)  65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 15, 15, 512)  2048       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 15, 15, 512)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 15, 15, 512)  4608       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 15, 15, 512)  2048       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 15, 15, 512)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 512)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 15, 15, 512)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 15, 15, 128)  65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 15, 15, 128)  512        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 15, 15, 128)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 15, 15, 128)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 15, 15, 512)  65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 15, 15, 512)  2048       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 15, 15, 512)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 15, 15, 512)  4608       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 15, 15, 512)  2048       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 15, 15, 512)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 512)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 15, 15, 512)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 15, 15, 128)  65536       ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 15, 15, 128)  512        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 15, 15, 128)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 15, 15, 128)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 15, 15, 768)  98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 15, 15, 768)  3072       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 15, 15, 768)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 15, 15, 768)  6912       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 15, 15, 768)  3072       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 15, 15, 768)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 768)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 32)     24608       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 768)    25344       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 15, 15, 768)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 15, 15, 160)  122880      ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 15, 15, 960)  153600      ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 15, 15, 960)  3840       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 15, 15, 960)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 15, 15, 960)  8640       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 15, 15, 960)  3840       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 15, 15, 960)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 960)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 15, 15, 960)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 15, 15, 160)  153600      ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 15, 15, 160)  640        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 15, 15, 160)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 15, 15, 160)  0           ['block5b_drop[0][0]',
# ...
#  block6l_expand_activation (Act  (None, 8, 8, 1536)  0           ['block6l_expand_bn[0][0]']
#  ivation)
#
#  block6l_dwconv2 (DepthwiseConv  (None, 8, 8, 1536)  13824       ['block6l_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6l_bn (BatchNormalization  (None, 8, 8, 1536)  6144        ['block6l_dwconv2[0][0]']
#  )
#
#  block6l_activation (Activation  (None, 8, 8, 1536)  0           ['block6l_bn[0][0]']
#  )
#
#  block6l_se_squeeze (GlobalAver  (None, 1536)        0           ['block6l_activation[0][0]']
#  agePooling2D)
#
#  block6l_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6l_se_squeeze[0][0]']
#
#  block6l_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multiply)   (None, 8, 8, 1536)   0           ['block6l_activation[0][0]',
#                                                                   'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv2D)  (None, 8, 8, 256)    393216      ['block6l_se_excite[0][0]']
#
#  block6l_project_bn (BatchNorma  (None, 8, 8, 256)   1024        ['block6l_project_conv[0][0]']
#  lization)
#
#  block6l_drop (Dropout)         (None, 8, 8, 256)    0           ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)              (None, 8, 8, 256)    0           ['block6l_drop[0][0]',
#                                                                   'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2D)   (None, 8, 8, 1536)   393216      ['block6l_add[0][0]']
#
#  block6m_expand_bn (BatchNormal  (None, 8, 8, 1536)  6144        ['block6m_expand_conv[0][0]']
#  ization)
#
#  block6m_expand_activation (Act  (None, 8, 8, 1536)  0           ['block6m_expand_bn[0][0]']
#  ivation)
#
#  block6m_dwconv2 (DepthwiseConv  (None, 8, 8, 1536)  13824       ['block6m_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6m_bn (BatchNormalization  (None, 8, 8, 1536)  6144        ['block6m_dwconv2[0][0]']
#  )
#
#  block6m_activation (Activation  (None, 8, 8, 1536)  0           ['block6m_bn[0][0]']
#  )
#
#  block6m_se_squeeze (GlobalAver  (None, 1536)        0           ['block6m_activation[0][0]']
#  agePooling2D)
#  block6m_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6m_se_squeeze[0][0]']
#
#  block6m_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multiply)   (None, 8, 8, 1536)   0           ['block6m_activation[0][0]',
#                                                                   'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv2D)  (None, 8, 8, 256)    393216      ['block6m_se_excite[0][0]']
#
#  block6m_project_bn (BatchNorma  (None, 8, 8, 256)   1024        ['block6m_project_conv[0][0]']
#  lization)
#
#  block6m_drop (Dropout)         (None, 8, 8, 256)    0           ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)              (None, 8, 8, 256)    0           ['block6m_drop[0][0]',
#                                                                   'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2D)   (None, 8, 8, 1536)   393216      ['block6m_add[0][0]']
#
#  block6n_expand_bn (BatchNormal  (None, 8, 8, 1536)  6144        ['block6n_expand_conv[0][0]']
#  ization)
#
#  block6n_expand_activation (Act  (None, 8, 8, 1536)  0           ['block6n_expand_bn[0][0]']
#  ivation)
#
#  block6n_dwconv2 (DepthwiseConv  (None, 8, 8, 1536)  13824       ['block6n_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6n_bn (BatchNormalization  (None, 8, 8, 1536)  6144        ['block6n_dwconv2[0][0]']
#  )
#
#  block6n_activation (Activation  (None, 8, 8, 1536)  0           ['block6n_bn[0][0]']
#  )
#
#  block6n_se_squeeze (GlobalAver  (None, 1536)        0           ['block6n_activation[0][0]']
#  agePooling2D)
#
#  block6n_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6n_se_squeeze[0][0]']
#
#  block6n_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multiply)   (None, 8, 8, 1536)   0           ['block6n_activation[0][0]',
#                                                                   'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv2D)  (None, 8, 8, 256)    393216      ['block6n_se_excite[0][0]']
#
#  block6n_project_bn (BatchNorma  (None, 8, 8, 256)   1024        ['block6n_project_conv[0][0]']
#  lization)
#
#  block6n_drop (Dropout)         (None, 8, 8, 256)    0           ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)              (None, 8, 8, 256)    0           ['block6n_drop[0][0]',
#                                                                   'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2D)   (None, 8, 8, 1536)   393216      ['block6n_add[0][0]']
#
#  block6o_expand_bn (BatchNormal  (None, 8, 8, 1536)  6144        ['block6o_expand_conv[0][0]']
#  ization)
#
#  block6o_expand_activation (Act  (None, 8, 8, 1536)  0           ['block6o_expand_bn[0][0]']
#  ivation)
#
#  block6o_dwconv2 (DepthwiseConv  (None, 8, 8, 1536)  13824       ['block6o_expand_activation[0][0]
#  2D)                                                             ']
#
#  block6o_bn (BatchNormalization  (None, 8, 8, 1536)  6144        ['block6o_dwconv2[0][0]']
#  )
#
#  block6o_activation (Activation  (None, 8, 8, 1536)  0           ['block6o_bn[0][0]']
#  )
#
#  block6o_se_squeeze (GlobalAver  (None, 1536)        0           ['block6o_activation[0][0]']
#  agePooling2D)
#
#  block6o_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6o_se_squeeze[0][0]']
#
#  block6o_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multiply)   (None, 8, 8, 1536)   0           ['block6o_activation[0][0]',
#                                                                   'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv2D)  (None, 8, 8, 256)    393216      ['block6o_se_excite[0][0]']
#
#  block6o_project_bn (BatchNorma  (None, 8, 8, 256)   1024        ['block6o_project_conv[0][0]']
#  lization)
#
#  block6o_drop (Dropout)         (None, 8, 8, 256)    0           ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)              (None, 8, 8, 256)    0           ['block6o_drop[0][0]',
#                                                                   'block6n_add[0][0]']
#
#  top_conv (Conv2D)              (None, 8, 8, 1280)   327680      ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 8, 8, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 8, 8, 1280)   0           ['top_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 20,331,360
# Trainable params: 20,177,488
# Non-trainable params: 153,872
# __________________________________________________________________________________________________
# None

# %%
outputs = tf.keras.layers.Dense(labels, activation='softmax')(base_model.output)
model = tf.keras.Model(inputs=base_model.input, outputs=outputs)

# %%
EPOCHS = 100
INIT_LR = 1e-4
Decay = 1e-5

# compile the model
opt = opt = tf.keras.optimizers.Adam(learning_rate=INIT_LR)

model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer=opt)

print("[INFO] Training network...")

# Train
checkpoint = ModelCheckpoint("OD_ENV2S_AD.h5", monitor = 'val_accuracy', verbose = 1, save_best_only = True, save_weights_only = False, mode = 'max')


history = model.fit(
    aug.flow(x_train, y_train, shuffle = False),
    validation_data = (x_test, y_test),
    validation_freq=1,
    batch_size = 32,
    callbacks = [checkpoint],
    epochs = EPOCHS,)
# Out:
# [INFO] Training network...
# Epoch 1/100
# 277/277 [==============================] - ETA: 0s - loss: 1.6126 - accuracy: 0.5802
# Epoch 1: val_accuracy improved from -inf to 0.82648, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 145s 433ms/step - loss: 1.6126 - accuracy: 0.5802 - val_loss: 0.6040 - val_accuracy: 0.8265
# Epoch 2/100
# 277/277 [==============================] - ETA: 0s - loss: 0.4506 - accuracy: 0.8642
# Epoch 2: val_accuracy improved from 0.82648 to 0.91279, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 105s 379ms/step - loss: 0.4506 - accuracy: 0.8642 - val_loss: 0.2765 - val_accuracy: 0.9128
# Epoch 3/100
# 277/277 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9564
# Epoch 3: val_accuracy improved from 0.91279 to 0.94623, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 105s 379ms/step - loss: 0.1648 - accuracy: 0.9564 - val_loss: 0.1856 - val_accuracy: 0.9462
# Epoch 4/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0818 - accuracy: 0.9785
# Epoch 4: val_accuracy improved from 0.94623 to 0.95210, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 107s 387ms/step - loss: 0.0818 - accuracy: 0.9785 - val_loss: 0.1552 - val_accuracy: 0.9521
# Epoch 5/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9861
# Epoch 5: val_accuracy improved from 0.95210 to 0.96521, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 105s 379ms/step - loss: 0.0514 - accuracy: 0.9861 - val_loss: 0.1150 - val_accuracy: 0.9652
# Epoch 6/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0373 - accuracy: 0.9907
# Epoch 6: val_accuracy did not improve from 0.96521
# 277/277 [==============================] - 104s 375ms/step - loss: 0.0373 - accuracy: 0.9907 - val_loss: 0.1373 - val_accuracy: 0.9602
# Epoch 7/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9925
# Epoch 7: val_accuracy did not improve from 0.96521
# 277/277 [==============================] - 104s 375ms/step - loss: 0.0283 - accuracy: 0.9925 - val_loss: 0.1412 - val_accuracy: 0.9611
# Epoch 8/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9931
# Epoch 8: val_accuracy did not improve from 0.96521
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0259 - accuracy: 0.9931 - val_loss: 0.1287 - val_accuracy: 0.9638
# Epoch 9/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9915
# Epoch 9: val_accuracy did not improve from 0.96521
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0327 - accuracy: 0.9915 - val_loss: 0.1474 - val_accuracy: 0.9575
# Epoch 10/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9916
# Epoch 10: val_accuracy did not improve from 0.96521
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0321 - accuracy: 0.9916 - val_loss: 0.1445 - val_accuracy: 0.9648
# Epoch 11/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9921
# Epoch 11: val_accuracy did not improve from 0.96521
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0279 - accuracy: 0.9921 - val_loss: 0.1283 - val_accuracy: 0.9611
# Epoch 12/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9941
# Epoch 12: val_accuracy improved from 0.96521 to 0.96792, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0222 - accuracy: 0.9941 - val_loss: 0.1078 - val_accuracy: 0.9679
# Epoch 13/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9959
# Epoch 13: val_accuracy improved from 0.96792 to 0.97153, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0152 - accuracy: 0.9959 - val_loss: 0.1089 - val_accuracy: 0.9715
# Epoch 14/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9946
# Epoch 14: val_accuracy did not improve from 0.97153
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0225 - accuracy: 0.9946 - val_loss: 0.1266 - val_accuracy: 0.9657
# Epoch 15/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9933
# Epoch 15: val_accuracy did not improve from 0.97153
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0238 - accuracy: 0.9933 - val_loss: 0.1611 - val_accuracy: 0.9566
# Epoch 16/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9953
# Epoch 16: val_accuracy improved from 0.97153 to 0.97379, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0167 - accuracy: 0.9953 - val_loss: 0.0997 - val_accuracy: 0.9738
# Epoch 17/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9930
# Epoch 17: val_accuracy did not improve from 0.97379
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0223 - accuracy: 0.9930 - val_loss: 0.1283 - val_accuracy: 0.9620
# Epoch 18/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9968
# Epoch 18: val_accuracy improved from 0.97379 to 0.97469, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0960 - val_accuracy: 0.9747
# Epoch 19/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9984
# Epoch 19: val_accuracy did not improve from 0.97469
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.1347 - val_accuracy: 0.9693
# Epoch 20/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 0.9922
# Epoch 20: val_accuracy did not improve from 0.97469
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0244 - accuracy: 0.9922 - val_loss: 0.1243 - val_accuracy: 0.9657
# Epoch 21/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9971
# Epoch 21: val_accuracy did not improve from 0.97469
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.1830 - val_accuracy: 0.9580
# Epoch 22/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9947
# Epoch 22: val_accuracy did not improve from 0.97469
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.1162 - val_accuracy: 0.9747
# Epoch 23/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9934
# Epoch 23: val_accuracy did not improve from 0.97469
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0187 - accuracy: 0.9934 - val_loss: 0.1490 - val_accuracy: 0.9602
# Epoch 24/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9968
# Epoch 24: val_accuracy did not improve from 0.97469
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.1028 - val_accuracy: 0.9733
# Epoch 25/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9971
# Epoch 25: val_accuracy improved from 0.97469 to 0.97741, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0911 - val_accuracy: 0.9774
# Epoch 26/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9990
# Epoch 26: val_accuracy improved from 0.97741 to 0.97876, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0886 - val_accuracy: 0.9788
# Epoch 27/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9974
# Epoch 27: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 0.1064 - val_accuracy: 0.9706
# Epoch 28/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9969
# Epoch 28: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.1182 - val_accuracy: 0.9738
# Epoch 29/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9946
# Epoch 29: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0188 - accuracy: 0.9946 - val_loss: 0.1655 - val_accuracy: 0.9616
# Epoch 30/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9953
# Epoch 30: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0168 - accuracy: 0.9953 - val_loss: 0.1162 - val_accuracy: 0.9720
# Epoch 31/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9964
# Epoch 31: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0137 - accuracy: 0.9964 - val_loss: 0.1228 - val_accuracy: 0.9706
# Epoch 32/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9981
# Epoch 32: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1355 - val_accuracy: 0.9661
# Epoch 33/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9974
# Epoch 33: val_accuracy did not improve from 0.97876
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.0991 - val_accuracy: 0.9751
# Epoch 34/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9998
# Epoch 34: val_accuracy improved from 0.97876 to 0.97967, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0880 - val_accuracy: 0.9797
# Epoch 35/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9969
# Epoch 35: val_accuracy did not improve from 0.97967
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.1127 - val_accuracy: 0.9729
# Epoch 36/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9986
# Epoch 36: val_accuracy did not improve from 0.97967
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.1124 - val_accuracy: 0.9756
# Epoch 37/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9985
# Epoch 37: val_accuracy did not improve from 0.97967
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.1340 - val_accuracy: 0.9729
# Epoch 38/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9942
# Epoch 38: val_accuracy did not improve from 0.97967
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.2109 - val_accuracy: 0.9575
# Epoch 39/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9967
# Epoch 39: val_accuracy did not improve from 0.97967
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0114 - accuracy: 0.9967 - val_loss: 0.0970 - val_accuracy: 0.9724
# Epoch 40/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9966
# Epoch 40: val_accuracy did not improve from 0.97967
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.2296 - val_accuracy: 0.9539
# Epoch 41/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9965
# Epoch 41: val_accuracy improved from 0.97967 to 0.98012, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0945 - val_accuracy: 0.9801
# Epoch 42/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.9968
# Epoch 42: val_accuracy did not improve from 0.98012
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.1111 - val_accuracy: 0.9729
# Epoch 43/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983
# Epoch 43: val_accuracy improved from 0.98012 to 0.98147, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0889 - val_accuracy: 0.9815
# Epoch 44/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 44: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0852 - val_accuracy: 0.9756
# Epoch 45/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990
# Epoch 45: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0729 - val_accuracy: 0.9774
# Epoch 46/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9985
# Epoch 46: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.0903 - val_accuracy: 0.9806
# Epoch 47/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9983
# Epoch 47: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.3147 - val_accuracy: 0.9263
# Epoch 48/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9972
# Epoch 48: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0115 - accuracy: 0.9972 - val_loss: 0.1336 - val_accuracy: 0.9688
# Epoch 49/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 49: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0900 - val_accuracy: 0.9788
# Epoch 50/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9975
# Epoch 50: val_accuracy did not improve from 0.98147
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.1706 - val_accuracy: 0.9715
# Epoch 51/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9969
# Epoch 51: val_accuracy improved from 0.98147 to 0.98328, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 105s 380ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.0733 - val_accuracy: 0.9833
# Epoch 52/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9991
# Epoch 52: val_accuracy improved from 0.98328 to 0.98690, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0598 - val_accuracy: 0.9869
# Epoch 53/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9995
# Epoch 53: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0781 - val_accuracy: 0.9824
# Epoch 54/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9979
# Epoch 54: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0113 - accuracy: 0.9979 - val_loss: 0.1507 - val_accuracy: 0.9688
# Epoch 55/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9971
# Epoch 55: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.1193 - val_accuracy: 0.9751
# Epoch 56/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9979
# Epoch 56: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.1186 - val_accuracy: 0.9779
# Epoch 57/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9983
# Epoch 57: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.1220 - val_accuracy: 0.9756
# Epoch 58/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9985
# Epoch 58: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 0.0857 - val_accuracy: 0.9797
# Epoch 59/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9989
# Epoch 59: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0822 - val_accuracy: 0.9801
# Epoch 60/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983
# Epoch 60: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1020 - val_accuracy: 0.9756
# Epoch 61/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9988
# Epoch 61: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0778 - val_accuracy: 0.9842
# Epoch 62/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994
# Epoch 62: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.1280 - val_accuracy: 0.9720
# Epoch 63/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9954
# Epoch 63: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0161 - accuracy: 0.9954 - val_loss: 0.1182 - val_accuracy: 0.9702
# Epoch 64/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9972
# Epoch 64: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.2287 - val_accuracy: 0.9571
# Epoch 65/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9973
# Epoch 65: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 0.1602 - val_accuracy: 0.9629
# Epoch 66/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9977
# Epoch 66: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0721 - val_accuracy: 0.9806
# Epoch 67/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9998
# Epoch 67: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0819 - val_accuracy: 0.9806
# Epoch 68/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9981
# Epoch 68: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.1096 - val_accuracy: 0.9729
# Epoch 69/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9976
# Epoch 69: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0877 - val_accuracy: 0.9797
# Epoch 70/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9994
# Epoch 70: val_accuracy did not improve from 0.98690
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0674 - val_accuracy: 0.9833
# Epoch 71/100
# 277/277 [==============================] - ETA: 0s - loss: 8.5277e-04 - accuracy: 1.0000
# Epoch 71: val_accuracy improved from 0.98690 to 0.98735, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 8.5277e-04 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9873
# Epoch 72/100
# 277/277 [==============================] - ETA: 0s - loss: 3.0153e-04 - accuracy: 1.0000
# Epoch 72: val_accuracy improved from 0.98735 to 0.98825, saving model to OD_ENV2S_AD.h5
# 277/277 [==============================] - 104s 376ms/step - loss: 3.0153e-04 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9883
# Epoch 73/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 73: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0839 - val_accuracy: 0.9810
# Epoch 74/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 74: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0739 - val_accuracy: 0.9851
# Epoch 75/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9995
# Epoch 75: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0759 - val_accuracy: 0.9819
# Epoch 76/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 76: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0886 - val_accuracy: 0.9783
# Epoch 77/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9930
# Epoch 77: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0263 - accuracy: 0.9930 - val_loss: 0.0776 - val_accuracy: 0.9801
# Epoch 78/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9980
# Epoch 78: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0885 - val_accuracy: 0.9792
# Epoch 79/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9986
# Epoch 79: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0844 - val_accuracy: 0.9806
# Epoch 80/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 80: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0707 - val_accuracy: 0.9837
# Epoch 81/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9998
# Epoch 81: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0804 - val_accuracy: 0.9797
# Epoch 82/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 82: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0807 - val_accuracy: 0.9824
# Epoch 83/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9975
# Epoch 83: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.1202 - val_accuracy: 0.9733
# Epoch 84/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9998
# Epoch 84: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0666 - val_accuracy: 0.9851
# Epoch 85/100
# 277/277 [==============================] - ETA: 0s - loss: 9.8509e-04 - accuracy: 0.9998
# Epoch 85: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 9.8509e-04 - accuracy: 0.9998 - val_loss: 0.0651 - val_accuracy: 0.9846
# Epoch 86/100
# 277/277 [==============================] - ETA: 0s - loss: 2.7460e-04 - accuracy: 1.0000
# Epoch 86: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 2.7460e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9873
# Epoch 87/100
# 277/277 [==============================] - ETA: 0s - loss: 1.9468e-04 - accuracy: 1.0000
# Epoch 87: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 1.9468e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9869
# Epoch 88/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9988
# Epoch 88: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.0667 - val_accuracy: 0.9855
# Epoch 89/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9969
# Epoch 89: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.1418 - val_accuracy: 0.9670
# Epoch 90/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9953
# Epoch 90: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.0861 - val_accuracy: 0.9788
# Epoch 91/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9982
# Epoch 91: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0480 - val_accuracy: 0.9873
# Epoch 92/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 92: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0531 - val_accuracy: 0.9869
# Epoch 93/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 93: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0560 - val_accuracy: 0.9873
# Epoch 94/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9986
# Epoch 94: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0595 - val_accuracy: 0.9864
# Epoch 95/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9995
# Epoch 95: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0702 - val_accuracy: 0.9828
# Epoch 96/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9985
# Epoch 96: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.1553 - val_accuracy: 0.9657
# Epoch 97/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994
# Epoch 97: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0812 - val_accuracy: 0.9833
# Epoch 98/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 98: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0885 - val_accuracy: 0.9824
# Epoch 99/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9986
# Epoch 99: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.3228 - val_accuracy: 0.9336
# Epoch 100/100
# 277/277 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9972
# Epoch 100: val_accuracy did not improve from 0.98825
# 277/277 [==============================] - 103s 372ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.1787 - val_accuracy: 0.9657

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 20})

plt.figure(figsize=(25, 15))
xmin = 0
xmax = 100
ymin = 0.0
ymax = 1.0
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(len(acc))
    
axes = plt.gca()
axes.set_xlim([xmin,xmax])
axes.set_ylim([ymin,ymax])

plt.plot(epochs, acc, 'g--', label = 'Training accuracy')
plt.plot(epochs, val_acc, 'g', label = 'Validation accuracy')
plt.title('Training and validation Accuracy')
plt.legend(bbox_to_anchor=(0.9, 0.1))

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
plt.rcParams.update({'font.size': 20})

plt.figure(figsize=(25, 15))
    #Plot the Result
xmin = 0
xmax = 100
ymin = 0.0
ymax = 3.0

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
    
axes = plt.gca()
axes.set_xlim([xmin,xmax])
axes.set_ylim([ymin,ymax])

plt.plot(epochs, loss, 'r--', label = 'Training Loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
plt.title('Training and validation loss')
plt.legend(bbox_to_anchor=(0.3, 1))

plt.grid()
plt.show()

# %%
model = load_model("OD_ENV2S_AD.h5")
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 70/70 [==============================] - 9s 93ms/step - loss: 0.0604 - accuracy: 0.9883
# Test Accuracy: 98.8251268863678
